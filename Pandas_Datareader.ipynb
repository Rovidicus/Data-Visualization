# %%
import datetime as dt
##  saving today as string for pandas DataReader
today = dt.datetime.now().strftime("%Y-%m-%d")
today
# Out:
# '2023-12-19'

# %%
start_date = '2001-01-01'
end_date = today

# %%
##  Pandas DataReader Import
import pandas_datareader as pdr
##  Get MSFT stock price for 2012-2020 from Yahoo Finance
msft = pdr.DataReader('MSFT','yahoo',start_date, end_date)
msft
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       2 import pandas_datareader as pdr
#       3 ##  Get MSFT stock price for 2012-2020 from Yahoo Finance
# ----> 4 msft = pdr.DataReader('MSFT','yahoo',start_date, end_date)
#       5 msft
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas_datareader\data.py:379, in DataReader(name, data_source, start, end, retry_count, pause, session, api_key)
#     367     raise NotImplementedError(msg)
#     369 if data_source == "yahoo":
#     370     return YahooDailyReader(
#     371         symbols=name,
#     372         start=start,
#     373         end=end,
#     374         adjust_price=False,
#     375         chunksize=25,
#     376         retry_count=retry_count,
#     377         pause=pause,
#     378         session=session,
# --> 379     ).read()
#     381 elif data_source == "iex":
#     382     return IEXDailyReader(
#     383         symbols=name,
#     384         start=start,
#    (...)
#     390         session=session,
#     391     ).read()
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas_datareader\base.py:253, in _DailyBaseReader.read(self)
#     251 # If a single symbol, (e.g., 'GOOG')
#     252 if isinstance(self.symbols, (string_types, int)):
# --> 253     df = self._read_one_data(self.url, params=self._get_params(self.symbols))
#     254 # Or multiple symbols, (e.g., ['GOOG', 'AAPL', 'MSFT'])
#     255 elif isinstance(self.symbols, DataFrame):
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas_datareader\yahoo\daily.py:153, in YahooDailyReader._read_one_data(self, url, params)
#     151 try:
#     152     j = json.loads(re.search(ptrn, resp.text, re.DOTALL).group(1))
# --> 153     data = j["context"]["dispatcher"]["stores"]["HistoricalPriceStore"]
#     154 except KeyError:
#     155     msg = "No data fetched for symbol {} using {}"
#
# TypeError: string indices must be integers

# %%
# in a notebook, use ! before a pip command 
# !pip install yfinance
# Out:
# Requirement already satisfied: yfinance in c:\users\rovidicus\anaconda3\envs\dojo-env\lib\site-packages (0.2.18)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\rovidicus\anaconda3\envs\dojo-env\lib\site-packages (from yfinance) (1.5.3)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\rovidicus\anaconda3\envs\dojo-env\lib\site-packages (from yfinance) (1.23.4)
# Requirement already satisfied: requests>=2.26 in c:\users\rovidicus\anaconda3\envs\dojo-env\lib\site-packages (from yfinance) (2.29.0)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\rovidicus\anaconda3\envs\dojo-env\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\rovidicus\anaconda3\envs\dojo-env\lib\site-packages (from yfinance) (4.9.2)
# Requirement already satisfied: appdirs>=1.4.4 in c:\users\rovidicus\anaconda3\envs\dojo-env\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pytz>=2022.5 in c:\users\rovidicus\anaconda3\envs\dojo-env\lib\site-packages (from yfinance) (2022.7.1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\rovidicus\anaconda3\envs\dojo-env\lib\site-packages (from yfinance) (2.3.8)
# Requirement already satisfied: cryptography>=3.3.2 in c:\users\rovidicus\anaconda3\envs\dojo-env\lib\site-packages (from yfinance) (39.0.1)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\rovidicus\anaconda3\envs\dojo-env\lib\site-packages (from yfinance) (4.12.2)
# Requirement already satisfied: html5lib>=1.1 in c:\users\rovidicus\anaconda3\envs\dojo-env\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\rovidicus\anaconda3\envs\dojo-env\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.4)
# Requirement already satisfied: cffi>=1.12 in c:\users\rovidicus\anaconda3\envs\dojo-env\lib\site-packages (from cryptography>=3.3.2->yfinance) (1.15.1)
# Requirement already satisfied: six>=1.9 in c:\users\rovidicus\anaconda3\envs\dojo-env\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\rovidicus\anaconda3\envs\dojo-env\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\rovidicus\anaconda3\envs\dojo-env\lib\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\rovidicus\anaconda3\envs\dojo-env\lib\site-packages (from requests>=2.26->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rovidicus\anaconda3\envs\dojo-env\lib\site-packages (from requests>=2.26->yfinance) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\rovidicus\anaconda3\envs\dojo-env\lib\site-packages (from requests>=2.26->yfinance) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rovidicus\anaconda3\envs\dojo-env\lib\site-packages (from requests>=2.26->yfinance) (2023.5.7)
# Requirement already satisfied: pycparser in c:\users\rovidicus\anaconda3\envs\dojo-env\lib\site-packages (from cffi>=1.12->cryptography>=3.3.2->yfinance) (2.21)

# %%
import yfinance as yfin
yfin.pdr_override()

# %%
import pandas_datareader.data as pdr

# %%
msft = pdr.get_data_yahoo('MSFT',start_date, end_date)
msft
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2001-01-02   22.062500   22.500000   21.437500   21.687500   13.445465
# 2001-01-03   21.593750   24.437500   21.562500   23.968750   14.859762
# 2001-01-04   23.906250   25.250000   23.437500   24.218750   15.014748
# 2001-01-05   24.250000   24.937500   23.781250   24.562500   15.227864
# 2001-01-08   24.468750   24.875000   23.343750   24.468750   15.169741
# ...                ...         ...         ...         ...         ...
# 2023-12-12  370.850006  374.420013  370.459991  374.380005  374.380005
# 2023-12-13  376.019989  377.640015  370.769989  374.369995  374.369995
# 2023-12-14  373.309998  373.760010  364.130005  365.929993  365.929993
# 2023-12-15  366.850006  372.399994  366.279999  370.730011  370.730011
# 2023-12-18  369.450012  373.000000  368.679993  372.649994  372.649994
#
#                Volume
# Date
# 2001-01-02   82413200
# 2001-01-03  135962200
# 2001-01-04  112397000
# 2001-01-05   93414600
# 2001-01-08   79817600
# ...               ...
# 2023-12-12   24838300
# 2023-12-13   30955500
# 2023-12-14   43277500
# 2023-12-15   78478200
# 2023-12-18   21802900
#
# [5777 rows x 6 columns]

# %%
# !pip install yfinance
import yfinance as yfin
yfin.pdr_override()
##  Pandas DataReader Import
import pandas_datareader.data as pdr
# example use with new function
msft = pdr.get_data_yahoo('MSFT',start_date, end_date)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
##  Get GOOGL price for 2012-2020 from Yahoo Finance
googl = pdr.get_data_yahoo('GOOGL',start_date, end_date)
googl
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2004-08-19    2.502503    2.604104    2.401401    2.511011    2.511011
# 2004-08-20    2.527778    2.729730    2.515015    2.710460    2.710460
# 2004-08-23    2.771522    2.839840    2.728979    2.737738    2.737738
# 2004-08-24    2.783784    2.792793    2.591842    2.624374    2.624374
# 2004-08-25    2.626627    2.702703    2.599600    2.652653    2.652653
# ...                ...         ...         ...         ...         ...
# 2023-12-12  131.809998  133.000000  131.259995  132.520004  132.520004
# 2023-12-13  133.380005  133.500000  131.570007  132.570007  132.570007
# 2023-12-14  133.380005  133.720001  129.690002  131.940002  131.940002
# 2023-12-15  131.619995  133.509995  131.179993  132.600006  132.600006
# 2023-12-18  132.630005  137.149994  132.429993  135.800003  135.800003
#
#                Volume
# Date
# 2004-08-19  893181924
# 2004-08-20  456686856
# 2004-08-23  365122512
# 2004-08-24  304946748
# 2004-08-25  183772044
# ...               ...
# 2023-12-12   29032800
# 2023-12-13   30104800
# 2023-12-14   38722400
# 2023-12-15   50815200
# 2023-12-18   32258000
#
# [4867 rows x 6 columns]

# %%
##  Get AAPL stock price for 2012-2020 from Yahoo Finance
apple = pdr.get_data_yahoo('AAPL',start_date, end_date)
apple
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2001-01-02    0.265625    0.272321    0.260045    0.265625    0.225165
# 2001-01-03    0.258929    0.297991    0.257813    0.292411    0.247871
# 2001-01-04    0.323940    0.330357    0.300223    0.304688    0.258278
# 2001-01-05    0.302455    0.310268    0.286830    0.292411    0.247871
# 2001-01-08    0.302455    0.303292    0.284598    0.295759    0.250709
# ...                ...         ...         ...         ...         ...
# 2023-12-12  193.080002  194.720001  191.720001  194.710007  194.710007
# 2023-12-13  195.089996  198.000000  194.850006  197.960007  197.960007
# 2023-12-14  198.020004  199.619995  196.160004  198.110001  198.110001
# 2023-12-15  197.529999  198.399994  197.000000  197.570007  197.570007
# 2023-12-18  196.089996  196.630005  194.389999  195.889999  195.889999
#
#                Volume
# Date
# 2001-01-02  452312000
# 2001-01-03  817073600
# 2001-01-04  739396000
# 2001-01-05  412356000
# 2001-01-08  373699200
# ...               ...
# 2023-12-12   52696900
# 2023-12-13   70404200
# 2023-12-14   66831600
# 2023-12-15  128256700
# 2023-12-18   55751900
#
# [5777 rows x 6 columns]

# %%
import pandas as pd

# %%
stocks_df = pd.DataFrame({"AAPL": apple['Adj Close'],
             "MSFT": msft['Adj Close'],
             'GOOGL': googl['Adj Close']})
stocks_df
# Out:
#                   AAPL        MSFT       GOOGL
# Date
# 2001-01-02    0.225165   13.445464         NaN
# 2001-01-03    0.247871   14.859755         NaN
# 2001-01-04    0.258278   15.014749         NaN
# 2001-01-05    0.247871   15.227859         NaN
# 2001-01-08    0.250709   15.169733         NaN
# ...                ...         ...         ...
# 2023-12-12  194.710007  374.380005  132.520004
# 2023-12-13  197.960007  374.369995  132.570007
# 2023-12-14  198.110001  365.929993  131.940002
# 2023-12-15  197.570007  370.730011  132.600006
# 2023-12-18  195.889999  372.649994  135.800003
#
# [5777 rows x 3 columns]

# %%
stocks_df.plot();
